# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = (zip(lats, lngs))
print(lat_lngs)
# Out:
# <zip object at 0x7f9bc1be77c0>

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
#print(coordinates)

# %%
cities = []

# %%
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)

# %%
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 621

# %%
# 6.2.6 
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c0cd3838432b4caa051e4762de64a1c9

# %%
import time
from datetime import datetime

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Second submission: Corrected for Description, which was missing
# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | cidreira
# Processing Record 2 of Set 1 | arraial do cabo
# Processing Record 3 of Set 1 | skorodnoye
# Processing Record 4 of Set 1 | sitka
# Processing Record 5 of Set 1 | sokolo
# Processing Record 6 of Set 1 | bluff
# Processing Record 7 of Set 1 | chumikan
# Processing Record 8 of Set 1 | doha
# Processing Record 9 of Set 1 | salalah
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | atherton
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | hamilton
# Processing Record 14 of Set 1 | nikolskoye
# Processing Record 15 of Set 1 | new norfolk
# Processing Record 16 of Set 1 | jamestown
# Processing Record 17 of Set 1 | cherskiy
# Processing Record 18 of Set 1 | tasiilaq
# Processing Record 19 of Set 1 | victoria
# Processing Record 20 of Set 1 | castro
# Processing Record 21 of Set 1 | lorengau
# Processing Record 22 of Set 1 | liepaja
# Processing Record 23 of Set 1 | thompson
# Processing Record 24 of Set 1 | bambous virieux
# Processing Record 25 of Set 1 | vaini
# Processing Record 26 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 27 of Set 1 | nanesti
# Processing Record 28 of Set 1 | denizli
# Processing Record 29 of Set 1 | bonavista
# Processing Record 30 of Set 1 | east london
# Processing Record 31 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 1 | san jeronimo
# Processing Record 34 of Set 1 | saldanha
# Processing Record 35 of Set 1 | sept-iles
# Processing Record 36 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 1 | olafsvik
# Processing Record 38 of Set 1 | mbandaka
# Processing Record 39 of Set 1 | rio casca
# Processing Record 40 of Set 1 | saint george
# Processing Record 41 of Set 1 | uzyn
# Processing Record 42 of Set 1 | pangnirtung
# Processing Record 43 of Set 1 | verkhnyaya inta
# Processing Record 44 of Set 1 | izmayil
# Processing Record 45 of Set 1 | aykhal
# Processing Record 46 of Set 1 | hobart
# Processing Record 47 of Set 1 | marica
# Processing Record 48 of Set 1 | lubbock
# Processing Record 49 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 50 of Set 1 | norman wells
# Processing Record 1 of Set 2 | devils lake
# Processing Record 2 of Set 2 | bacolod
# Processing Record 3 of Set 2 | hermanus
# Processing Record 4 of Set 2 | luderitz
# Processing Record 5 of Set 2 | mataura
# Processing Record 6 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 7 of Set 2 | punta arenas
# Processing Record 8 of Set 2 | puerto ayora
# Processing Record 9 of Set 2 | tiksi
# Processing Record 10 of Set 2 | stettler
# Processing Record 11 of Set 2 | svetlyy
# Processing Record 12 of Set 2 | sandwick
# Processing Record 13 of Set 2 | port elizabeth
# Processing Record 14 of Set 2 | inirida
# Processing Record 15 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 16 of Set 2 | moroni
# Processing Record 17 of Set 2 | maua
# Processing Record 18 of Set 2 | rio de janeiro
# Processing Record 19 of Set 2 | alyangula
# Processing Record 20 of Set 2 | constitucion
# Processing Record 21 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 2 | mahebourg
# Processing Record 23 of Set 2 | yar-sale
# Processing Record 24 of Set 2 | kaifeng
# Processing Record 25 of Set 2 | bethel
# Processing Record 26 of Set 2 | kuching
# Processing Record 27 of Set 2 | nanortalik
# Processing Record 28 of Set 2 | puerto armuelles
# Processing Record 29 of Set 2 | makokou
# Processing Record 30 of Set 2 | jiddah
# City not found. Skipping...
# Processing Record 31 of Set 2 | bredasdorp
# Processing Record 32 of Set 2 | krasnoselkup
# Processing Record 33 of Set 2 | esperance
# Processing Record 34 of Set 2 | noumea
# Processing Record 35 of Set 2 | hambantota
# Processing Record 36 of Set 2 | carutapera
# Processing Record 37 of Set 2 | busselton
# Processing Record 38 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 2 | gunnedah
# Processing Record 40 of Set 2 | kadipur
# Processing Record 41 of Set 2 | bud
# Processing Record 42 of Set 2 | rocky mountain house
# Processing Record 43 of Set 2 | chokurdakh
# Processing Record 44 of Set 2 | havre-saint-pierre
# Processing Record 45 of Set 2 | butaritari
# Processing Record 46 of Set 2 | general roca
# Processing Record 47 of Set 2 | caravelas
# Processing Record 48 of Set 2 | sangmelima
# Processing Record 49 of Set 2 | dikson
# Processing Record 50 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 3 | kapaa
# Processing Record 2 of Set 3 | freeport
# Processing Record 3 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 3 | kargasok
# Processing Record 5 of Set 3 | santa maria
# Processing Record 6 of Set 3 | atuona
# Processing Record 7 of Set 3 | hilo
# Processing Record 8 of Set 3 | skjervoy
# Processing Record 9 of Set 3 | north bend
# Processing Record 10 of Set 3 | tuktoyaktuk
# Processing Record 11 of Set 3 | qaanaaq
# Processing Record 12 of Set 3 | portland
# Processing Record 13 of Set 3 | pevek
# Processing Record 14 of Set 3 | satitoa
# City not found. Skipping...
# Processing Record 15 of Set 3 | klaksvik
# Processing Record 16 of Set 3 | ancud
# Processing Record 17 of Set 3 | cape town
# Processing Record 18 of Set 3 | faanui
# Processing Record 19 of Set 3 | iqaluit
# Processing Record 20 of Set 3 | port alfred
# Processing Record 21 of Set 3 | provideniya
# Processing Record 22 of Set 3 | paciran
# Processing Record 23 of Set 3 | ulladulla
# Processing Record 24 of Set 3 | kruisfontein
# Processing Record 25 of Set 3 | grindavik
# Processing Record 26 of Set 3 | carnarvon
# Processing Record 27 of Set 3 | lebu
# Processing Record 28 of Set 3 | the valley
# Processing Record 29 of Set 3 | pangody
# Processing Record 30 of Set 3 | makakilo city
# Processing Record 31 of Set 3 | viljoenskroon
# Processing Record 32 of Set 3 | baie-comeau
# Processing Record 33 of Set 3 | opuwo
# Processing Record 34 of Set 3 | georgetown
# Processing Record 35 of Set 3 | ignatovka
# Processing Record 36 of Set 3 | ahipara
# Processing Record 37 of Set 3 | kaitangata
# Processing Record 38 of Set 3 | baykit
# Processing Record 39 of Set 3 | hunterville
# Processing Record 40 of Set 3 | mbanza-ngungu
# Processing Record 41 of Set 3 | kommunar
# Processing Record 42 of Set 3 | torbay
# Processing Record 43 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 3 | oranjestad
# Processing Record 45 of Set 3 | boyolangu
# Processing Record 46 of Set 3 | kavaratti
# Processing Record 47 of Set 3 | komsomolskiy
# Processing Record 48 of Set 3 | san quintin
# Processing Record 49 of Set 3 | visaginas
# Processing Record 50 of Set 3 | ndiekro
# City not found. Skipping...
# Processing Record 1 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 4 | picota
# Processing Record 3 of Set 4 | avarua
# Processing Record 4 of Set 4 | marawi
# Processing Record 5 of Set 4 | yaqui
# Processing Record 6 of Set 4 | muli
# Processing Record 7 of Set 4 | roald
# Processing Record 8 of Set 4 | san patricio
# Processing Record 9 of Set 4 | artyom
# Processing Record 10 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 4 | vani
# Processing Record 12 of Set 4 | coihaique
# Processing Record 13 of Set 4 | ilhabela
# Processing Record 14 of Set 4 | ribeira grande
# Processing Record 15 of Set 4 | la mata
# Processing Record 16 of Set 4 | staunton
# Processing Record 17 of Set 4 | twin falls
# Processing Record 18 of Set 4 | port hedland
# Processing Record 19 of Set 4 | oyem
# Processing Record 20 of Set 4 | upernavik
# Processing Record 21 of Set 4 | sinnamary
# Processing Record 22 of Set 4 | phatthalung
# Processing Record 23 of Set 4 | qandala
# Processing Record 24 of Set 4 | genhe
# Processing Record 25 of Set 4 | ibra
# Processing Record 26 of Set 4 | le havre
# Processing Record 27 of Set 4 | namatanai
# Processing Record 28 of Set 4 | mecca
# Processing Record 29 of Set 4 | albany
# Processing Record 30 of Set 4 | gwanda
# Processing Record 31 of Set 4 | camalu
# Processing Record 32 of Set 4 | ambon
# Processing Record 33 of Set 4 | pacific grove
# Processing Record 34 of Set 4 | tuatapere
# Processing Record 35 of Set 4 | lotofaga
# Processing Record 36 of Set 4 | warmbad
# Processing Record 37 of Set 4 | dzhusaly
# City not found. Skipping...
# Processing Record 38 of Set 4 | adrar
# Processing Record 39 of Set 4 | fort-shevchenko
# Processing Record 40 of Set 4 | felidhoo
# City not found. Skipping...
# Processing Record 41 of Set 4 | leh
# Processing Record 42 of Set 4 | srednekolymsk
# Processing Record 43 of Set 4 | talara
# Processing Record 44 of Set 4 | lagoa
# Processing Record 45 of Set 4 | lindi
# Processing Record 46 of Set 4 | taitung
# Processing Record 47 of Set 4 | saint-georges
# Processing Record 48 of Set 4 | tutoia
# Processing Record 49 of Set 4 | fairbanks
# Processing Record 50 of Set 4 | salta
# Processing Record 1 of Set 5 | port lavaca
# Processing Record 2 of Set 5 | ahmadnagar
# Processing Record 3 of Set 5 | minbu
# Processing Record 4 of Set 5 | vila franca do campo
# Processing Record 5 of Set 5 | saint-philippe
# Processing Record 6 of Set 5 | yokadouma
# Processing Record 7 of Set 5 | saskylakh
# Processing Record 8 of Set 5 | sao felix do xingu
# Processing Record 9 of Set 5 | blanquefort
# Processing Record 10 of Set 5 | gitarama
# Processing Record 11 of Set 5 | altay
# Processing Record 12 of Set 5 | yulara
# Processing Record 13 of Set 5 | sioux lookout
# Processing Record 14 of Set 5 | batagay
# Processing Record 15 of Set 5 | cayenne
# Processing Record 16 of Set 5 | nuuk
# Processing Record 17 of Set 5 | marsh harbour
# Processing Record 18 of Set 5 | ucluelet
# Processing Record 19 of Set 5 | traiguen
# Processing Record 20 of Set 5 | matara
# Processing Record 21 of Set 5 | sapernoye
# Processing Record 22 of Set 5 | bilma
# Processing Record 23 of Set 5 | utete
# Processing Record 24 of Set 5 | saltpond
# Processing Record 25 of Set 5 | olavarria
# Processing Record 26 of Set 5 | vaitape
# Processing Record 27 of Set 5 | herat
# Processing Record 28 of Set 5 | koulamoutou
# Processing Record 29 of Set 5 | vestmannaeyjar
# Processing Record 30 of Set 5 | mocuba
# Processing Record 31 of Set 5 | vao
# Processing Record 32 of Set 5 | millinocket
# Processing Record 33 of Set 5 | darhan
# Processing Record 34 of Set 5 | narsaq
# Processing Record 35 of Set 5 | yellowknife
# Processing Record 36 of Set 5 | kyra
# Processing Record 37 of Set 5 | chuy
# Processing Record 38 of Set 5 | inta
# Processing Record 39 of Set 5 | shiroishi
# Processing Record 40 of Set 5 | mopipi
# Processing Record 41 of Set 5 | nhulunbuy
# Processing Record 42 of Set 5 | airai
# Processing Record 43 of Set 5 | salekhard
# Processing Record 44 of Set 5 | shache
# Processing Record 45 of Set 5 | tautira
# Processing Record 46 of Set 5 | elmira
# Processing Record 47 of Set 5 | chapais
# Processing Record 48 of Set 5 | kushmurun
# Processing Record 49 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 5 | viedma
# Processing Record 1 of Set 6 | sao paulo de olivenca
# Processing Record 2 of Set 6 | san policarpo
# Processing Record 3 of Set 6 | praia da vitoria
# Processing Record 4 of Set 6 | havelock
# Processing Record 5 of Set 6 | barrow
# Processing Record 6 of Set 6 | isla mujeres
# Processing Record 7 of Set 6 | kavieng
# Processing Record 8 of Set 6 | lasa
# Processing Record 9 of Set 6 | akureyri
# Processing Record 10 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 11 of Set 6 | mar del plata
# Processing Record 12 of Set 6 | kaliwungu
# Processing Record 13 of Set 6 | tura
# Processing Record 14 of Set 6 | bur gabo
# City not found. Skipping...
# Processing Record 15 of Set 6 | huarmey
# Processing Record 16 of Set 6 | shakawe
# Processing Record 17 of Set 6 | swellendam
# Processing Record 18 of Set 6 | rundu
# Processing Record 19 of Set 6 | te anau
# Processing Record 20 of Set 6 | ketchikan
# Processing Record 21 of Set 6 | yalta
# Processing Record 22 of Set 6 | hefei
# Processing Record 23 of Set 6 | walvis bay
# Processing Record 24 of Set 6 | merauke
# Processing Record 25 of Set 6 | hanting
# Processing Record 26 of Set 6 | cockburn harbour
# City not found. Skipping...
# Processing Record 27 of Set 6 | kaupanger
# Processing Record 28 of Set 6 | rolim de moura
# City not found. Skipping...
# Processing Record 29 of Set 6 | kalur kot
# Processing Record 30 of Set 6 | paraiso
# Processing Record 31 of Set 6 | mount isa
# Processing Record 32 of Set 6 | saint charles
# Processing Record 33 of Set 6 | nuevo progreso
# Processing Record 34 of Set 6 | guerrero negro
# Processing Record 35 of Set 6 | jumla
# Processing Record 36 of Set 6 | sangre grande
# Processing Record 37 of Set 6 | koungou
# Processing Record 38 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 39 of Set 6 | hingatungan
# Processing Record 40 of Set 6 | richards bay
# Processing Record 41 of Set 6 | road town
# Processing Record 42 of Set 6 | mandan
# Processing Record 43 of Set 6 | alofi
# Processing Record 44 of Set 6 | poum
# Processing Record 45 of Set 6 | laguna
# Processing Record 46 of Set 6 | pella
# Processing Record 47 of Set 6 | mizdah
# Processing Record 48 of Set 6 | qeshm
# Processing Record 49 of Set 6 | severo-kurilsk
# Processing Record 50 of Set 6 | kuusamo
# Processing Record 1 of Set 7 | ouadda
# Processing Record 2 of Set 7 | hithadhoo
# Processing Record 3 of Set 7 | yacuiba
# Processing Record 4 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 5 of Set 7 | oromocto
# Processing Record 6 of Set 7 | kodiak
# Processing Record 7 of Set 7 | ixtapa
# Processing Record 8 of Set 7 | shingu
# Processing Record 9 of Set 7 | kamenka
# Processing Record 10 of Set 7 | fethiye
# Processing Record 11 of Set 7 | acajutla
# Processing Record 12 of Set 7 | beringovskiy
# Processing Record 13 of Set 7 | beyneu
# Processing Record 14 of Set 7 | bengkulu
# Processing Record 15 of Set 7 | yunjinghong
# City not found. Skipping...
# Processing Record 16 of Set 7 | jalpan
# Processing Record 17 of Set 7 | port blair
# Processing Record 18 of Set 7 | masuguru
# Processing Record 19 of Set 7 | benguela
# Processing Record 20 of Set 7 | lapeer
# Processing Record 21 of Set 7 | naftah
# City not found. Skipping...
# Processing Record 22 of Set 7 | tsuruoka
# Processing Record 23 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 7 | mporokoso
# Processing Record 25 of Set 7 | dubbo
# Processing Record 26 of Set 7 | lata
# Processing Record 27 of Set 7 | sibolga
# Processing Record 28 of Set 7 | labuhan
# Processing Record 29 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 7 | sao filipe
# Processing Record 31 of Set 7 | hecun
# Processing Record 32 of Set 7 | manasa
# Processing Record 33 of Set 7 | mount gambier
# Processing Record 34 of Set 7 | zhanaozen
# Processing Record 35 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 36 of Set 7 | prince george
# Processing Record 37 of Set 7 | udachnyy
# Processing Record 38 of Set 7 | cabo san lucas
# Processing Record 39 of Set 7 | harper
# Processing Record 40 of Set 7 | san ramon
# Processing Record 41 of Set 7 | thung song
# Processing Record 42 of Set 7 | vyazniki
# Processing Record 43 of Set 7 | henties bay
# Processing Record 44 of Set 7 | ponta do sol
# Processing Record 45 of Set 7 | dalbandin
# Processing Record 46 of Set 7 | monrovia
# Processing Record 47 of Set 7 | zaranj
# Processing Record 48 of Set 7 | port shepstone
# Processing Record 49 of Set 7 | flinders
# Processing Record 50 of Set 7 | ladybank
# Processing Record 1 of Set 8 | sonoita
# Processing Record 2 of Set 8 | yangambi
# Processing Record 3 of Set 8 | port-cartier
# Processing Record 4 of Set 8 | tazovskiy
# Processing Record 5 of Set 8 | pisco
# Processing Record 6 of Set 8 | kharsia
# Processing Record 7 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 8 of Set 8 | rio tercero
# Processing Record 9 of Set 8 | boguchany
# Processing Record 10 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 11 of Set 8 | tucuman
# Processing Record 12 of Set 8 | aldan
# Processing Record 13 of Set 8 | longonjo
# Processing Record 14 of Set 8 | kahului
# Processing Record 15 of Set 8 | karpathos
# Processing Record 16 of Set 8 | banamba
# Processing Record 17 of Set 8 | okato
# Processing Record 18 of Set 8 | fallon
# Processing Record 19 of Set 8 | qaqortoq
# Processing Record 20 of Set 8 | puerto escondido
# Processing Record 21 of Set 8 | sao luiz gonzaga
# Processing Record 22 of Set 8 | cockburn town
# Processing Record 23 of Set 8 | anadyr
# Processing Record 24 of Set 8 | talnakh
# Processing Record 25 of Set 8 | isangel
# Processing Record 26 of Set 8 | guajara-mirim
# City not found. Skipping...
# Processing Record 27 of Set 8 | bolshiye uki
# City not found. Skipping...
# Processing Record 28 of Set 8 | saint-esteve
# Processing Record 29 of Set 8 | nabire
# Processing Record 30 of Set 8 | the pas
# Processing Record 31 of Set 8 | barra patuca
# Processing Record 32 of Set 8 | norsup
# Processing Record 33 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 8 | potosi
# Processing Record 35 of Set 8 | vardo
# Processing Record 36 of Set 8 | dingle
# Processing Record 37 of Set 8 | cao bang
# Processing Record 38 of Set 8 | bonthe
# Processing Record 39 of Set 8 | kingsport
# Processing Record 40 of Set 8 | souillac
# Processing Record 41 of Set 8 | cortez
# Processing Record 42 of Set 8 | hovd
# Processing Record 43 of Set 8 | presidencia roque saenz pena
# Processing Record 44 of Set 8 | mozarlandia
# Processing Record 45 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 46 of Set 8 | labytnangi
# Processing Record 47 of Set 8 | vostok
# Processing Record 48 of Set 8 | chandbali
# Processing Record 49 of Set 8 | hervey bay
# Processing Record 50 of Set 8 | omsukchan
# Processing Record 1 of Set 9 | dalvik
# Processing Record 2 of Set 9 | nacala
# Processing Record 3 of Set 9 | manavalakurichi
# Processing Record 4 of Set 9 | longyearbyen
# Processing Record 5 of Set 9 | royal leamington spa
# Processing Record 6 of Set 9 | aasiaat
# Processing Record 7 of Set 9 | rosario
# Processing Record 8 of Set 9 | batemans bay
# Processing Record 9 of Set 9 | mandalgovi
# Processing Record 10 of Set 9 | orange
# Processing Record 11 of Set 9 | yatou
# Processing Record 12 of Set 9 | bushehr
# Processing Record 13 of Set 9 | miraflores
# Processing Record 14 of Set 9 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 15 of Set 9 | kabo
# Processing Record 16 of Set 9 | cap malheureux
# Processing Record 17 of Set 9 | san carlos de bariloche
# Processing Record 18 of Set 9 | okhotsk
# Processing Record 19 of Set 9 | raudeberg
# Processing Record 20 of Set 9 | pishin
# Processing Record 21 of Set 9 | muros
# Processing Record 22 of Set 9 | stephenville
# Processing Record 23 of Set 9 | dedougou
# Processing Record 24 of Set 9 | broken hill
# Processing Record 25 of Set 9 | adelaide
# Processing Record 26 of Set 9 | murindo
# Processing Record 27 of Set 9 | wanning
# Processing Record 28 of Set 9 | formoso do araguaia
# City not found. Skipping...
# Processing Record 29 of Set 9 | koslan
# Processing Record 30 of Set 9 | vesyegonsk
# Processing Record 31 of Set 9 | vyborg
# Processing Record 32 of Set 9 | koumac
# Processing Record 33 of Set 9 | clyde river
# Processing Record 34 of Set 9 | coquimbo
# Processing Record 35 of Set 9 | yumen
# Processing Record 36 of Set 9 | touros
# Processing Record 37 of Set 9 | nioro
# Processing Record 38 of Set 9 | magam
# Processing Record 39 of Set 9 | kachiry
# Processing Record 40 of Set 9 | takoradi
# Processing Record 41 of Set 9 | nelson bay
# Processing Record 42 of Set 9 | cam ranh
# Processing Record 43 of Set 9 | antofagasta
# Processing Record 44 of Set 9 | zelenoborsk
# Processing Record 45 of Set 9 | huilong
# Processing Record 46 of Set 9 | galiwinku
# City not found. Skipping...
# Processing Record 47 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 48 of Set 9 | najran
# Processing Record 49 of Set 9 | merritt island
# Processing Record 50 of Set 9 | shieli
# Processing Record 1 of Set 10 | ilulissat
# Processing Record 2 of Set 10 | algiers
# Processing Record 3 of Set 10 | khatanga
# Processing Record 4 of Set 10 | namibe
# Processing Record 5 of Set 10 | florianopolis
# Processing Record 6 of Set 10 | rio gallegos
# Processing Record 7 of Set 10 | gamba
# Processing Record 8 of Set 10 | gat
# Processing Record 9 of Set 10 | hukuntsi
# Processing Record 10 of Set 10 | boa vista
# Processing Record 11 of Set 10 | onverwacht
# Processing Record 12 of Set 10 | nyurba
# Processing Record 13 of Set 10 | redlands
# Processing Record 14 of Set 10 | bubaque
# Processing Record 15 of Set 10 | victor harbor
# Processing Record 16 of Set 10 | westport
# Processing Record 17 of Set 10 | lompoc
# Processing Record 18 of Set 10 | coolum beach
# Processing Record 19 of Set 10 | arlit
# Processing Record 20 of Set 10 | karratha
# Processing Record 21 of Set 10 | deputatskiy
# Processing Record 22 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 10 | winnemucca
# Processing Record 24 of Set 10 | carauari
# Processing Record 25 of Set 10 | wyndham
# Processing Record 26 of Set 10 | sibu
# Processing Record 27 of Set 10 | beira
# Processing Record 28 of Set 10 | superior
# Processing Record 29 of Set 10 | shelburne
# Processing Record 30 of Set 10 | tigil
# Processing Record 31 of Set 10 | tsogni
# Processing Record 32 of Set 10 | correntina
# Processing Record 33 of Set 10 | calarasi
# Processing Record 34 of Set 10 | lavrentiya
# Processing Record 35 of Set 10 | port lincoln
# Processing Record 36 of Set 10 | kambove
# Processing Record 37 of Set 10 | guaymas
# Processing Record 38 of Set 10 | fredericksburg
# Processing Record 39 of Set 10 | mayo
# Processing Record 40 of Set 10 | rock sound
# Processing Record 41 of Set 10 | chipinge
# Processing Record 42 of Set 10 | miri
# Processing Record 43 of Set 10 | dulce nombre de culmi
# Processing Record 44 of Set 10 | nantucket
# Processing Record 45 of Set 10 | irara
# Processing Record 46 of Set 10 | padang
# Processing Record 47 of Set 10 | samarai
# Processing Record 48 of Set 10 | balkhash
# Processing Record 49 of Set 10 | gambo
# Processing Record 50 of Set 10 | zhigansk
# Processing Record 1 of Set 11 | surt
# Processing Record 2 of Set 11 | athmallik
# Processing Record 3 of Set 11 | ambovombe
# Processing Record 4 of Set 11 | batabano
# Processing Record 5 of Set 11 | mallaig
# Processing Record 6 of Set 11 | yamada
# Processing Record 7 of Set 11 | huadian
# Processing Record 8 of Set 11 | ust-maya
# Processing Record 9 of Set 11 | balabac
# Processing Record 10 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 11 of Set 11 | paita
# Processing Record 12 of Set 11 | diamantino
# Processing Record 13 of Set 11 | teya
# Processing Record 14 of Set 11 | egvekinot
# Processing Record 15 of Set 11 | waipawa
# Processing Record 16 of Set 11 | jiuquan
# Processing Record 17 of Set 11 | jorochito
# Processing Record 18 of Set 11 | emerald
# Processing Record 19 of Set 11 | tabukiniberu
# City not found. Skipping...
# Processing Record 20 of Set 11 | kars
# Processing Record 21 of Set 11 | chicama
# Processing Record 22 of Set 11 | san pedro
# Processing Record 23 of Set 11 | ayan
# Processing Record 24 of Set 11 | mabaruma
# Processing Record 25 of Set 11 | esso
# Processing Record 26 of Set 11 | betioky
# Processing Record 27 of Set 11 | trelew
# Processing Record 28 of Set 11 | navirai
# Processing Record 29 of Set 11 | salme
# Processing Record 30 of Set 11 | sukhoverkovo
# City not found. Skipping...
# Processing Record 31 of Set 11 | cherepovets
# Processing Record 32 of Set 11 | narasannapeta
# Processing Record 33 of Set 11 | maldonado
# Processing Record 34 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 11 | bomet
# Processing Record 36 of Set 11 | matadi
# Processing Record 37 of Set 11 | marsabit
# Processing Record 38 of Set 11 | faya
# Processing Record 39 of Set 11 | atambua
# Processing Record 40 of Set 11 | nouadhibou
# Processing Record 41 of Set 11 | guadalajara
# Processing Record 42 of Set 11 | abu dhabi
# Processing Record 43 of Set 11 | berlevag
# Processing Record 44 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 45 of Set 11 | lokken verk
# City not found. Skipping...
# Processing Record 46 of Set 11 | alta floresta
# Processing Record 47 of Set 11 | tomatlan
# Processing Record 48 of Set 11 | kilindoni
# Processing Record 49 of Set 11 | tongliao
# Processing Record 50 of Set 11 | myanaung
# Processing Record 1 of Set 12 | fortuna
# Processing Record 2 of Set 12 | rio grande
# Processing Record 3 of Set 12 | yeysk
# Processing Record 4 of Set 12 | berea
# Processing Record 5 of Set 12 | rosarito
# Processing Record 6 of Set 12 | saint-joseph
# Processing Record 7 of Set 12 | alice springs
# Processing Record 8 of Set 12 | harlingen
# Processing Record 9 of Set 12 | nome
# Processing Record 10 of Set 12 | chinsali
# Processing Record 11 of Set 12 | itupiranga
# Processing Record 12 of Set 12 | svetlogorsk
# Processing Record 13 of Set 12 | saint-augustin
# Processing Record 14 of Set 12 | minas
# Processing Record 15 of Set 12 | estelle
# Processing Record 16 of Set 12 | dubti
# Processing Record 17 of Set 12 | peniche
# Processing Record 18 of Set 12 | tabuk
# Processing Record 19 of Set 12 | la rioja
# Processing Record 20 of Set 12 | tulcingo
# City not found. Skipping...
# Processing Record 21 of Set 12 | paamiut
# Processing Record 22 of Set 12 | ashington
# Processing Record 23 of Set 12 | vanimo
# Processing Record 24 of Set 12 | raga
# Processing Record 25 of Set 12 | khatauli
# Processing Record 26 of Set 12 | we
# City not found. Skipping...
# Processing Record 27 of Set 12 | northam
# Processing Record 28 of Set 12 | saint-pierre
# Processing Record 29 of Set 12 | aklavik
# Processing Record 30 of Set 12 | glubokoe
# City not found. Skipping...
# Processing Record 31 of Set 12 | mwinilunga
# Processing Record 32 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 33 of Set 12 | kichera
# Processing Record 34 of Set 12 | bilibino
# Processing Record 35 of Set 12 | kedougou
# Processing Record 36 of Set 12 | katsuura
# Processing Record 37 of Set 12 | segou
# Processing Record 38 of Set 12 | yoichi
# Processing Record 39 of Set 12 | balbalan
# Processing Record 40 of Set 12 | shimoda
# Processing Record 41 of Set 12 | oktyabrskoye
# Processing Record 42 of Set 12 | aquiraz
# Processing Record 43 of Set 12 | koutsouras
# Processing Record 44 of Set 12 | paso de los toros
# Processing Record 45 of Set 12 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 12 | wiarton
# Processing Record 47 of Set 12 | jilib
# Processing Record 48 of Set 12 | medicine hat
# Processing Record 49 of Set 12 | peace river
# Processing Record 50 of Set 12 | whitehorse
# Processing Record 1 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 2 of Set 13 | zyryanka
# Processing Record 3 of Set 13 | allacapan
# Processing Record 4 of Set 13 | panacan
# Processing Record 5 of Set 13 | russell
# Processing Record 6 of Set 13 | seydi
# Processing Record 7 of Set 13 | port hardy
# Processing Record 8 of Set 13 | bardiyah
# Processing Record 9 of Set 13 | olden
# Processing Record 10 of Set 13 | batagay-alyta
# Processing Record 11 of Set 13 | smidovich
# Processing Record 12 of Set 13 | vieste
# Processing Record 13 of Set 13 | asau
# Processing Record 14 of Set 13 | lakhnau
# Processing Record 15 of Set 13 | pribelskiy
# City not found. Skipping...
# Processing Record 16 of Set 13 | juneau
# Processing Record 17 of Set 13 | illapel
# Processing Record 18 of Set 13 | tual
# Processing Record 19 of Set 13 | bingol
# Processing Record 20 of Set 13 | san andres
# Processing Record 21 of Set 13 | dalby
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(cities)
# Out:
# 621

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0         Cidreira -30.1811  -50.2056     58.41           clear sky        90
# 1  Arraial Do Cabo -22.9661  -42.0278     68.11           clear sky        71
# 2       Skorodnoye  51.0710   37.2276     57.33       broken clouds        65
# 3            Sitka  57.0531 -135.3300     57.09          light rain        94
# 4           Sokolo  14.7328   -6.1219     85.35          few clouds        51
#
#    Cloudiness  Wind Speed Country
# 0           2        9.10      BR
# 1           0       11.03      BR
# 2          72        8.81      RU
# 3         100        6.91      US
# 4          11        9.24      ML

# %%
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Reorder the columns in the order you want them to appear.
new_column_order = ["City", "Country", "Lat",
                    "Lng", "Max Temp", "Humidity", 
                    "Cloudiness", "Wind Speed", 
                    "Current Description"] 

# Assign a new or the same DataFrame the new column order.
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Cidreira      BR -30.1811  -50.2056     58.41        90           2
# 1  Arraial Do Cabo      BR -22.9661  -42.0278     68.11        71           0
# 2       Skorodnoye      RU  51.0710   37.2276     57.33        65          72
# 3            Sitka      US  57.0531 -135.3300     57.09        94         100
# 4           Sokolo      ML  14.7328   -6.1219     85.35        51          11
# 5            Bluff      NZ -46.6000  168.3333     51.80        74         100
# 6         Chumikan      RU  54.7183  135.3150     54.09        98         100
# 7             Doha      QA  25.2867   51.5333     93.18        68           0
# 8          Salalah      OM  17.0151   54.0924     77.09        88          75
# 9          Rikitea      PF -23.1203 -134.9692     72.10        74         100
#
#    Wind Speed Current Description
# 0        9.10           clear sky
# 1       11.03           clear sky
# 2        8.81       broken clouds
# 3        6.91          light rain
# 4        9.24          few clouds
# 5       16.87     overcast clouds
# 6        7.47          light rain
# 7        6.91           clear sky
# 8        9.22       broken clouds
# 9       24.45          light rain

# %%
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
